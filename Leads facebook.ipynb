# %%
import pandas as pd

# %%
promotio_register = pd.read_excel(open("./Data/Registro promocion 2018.xlsx", 'rb'), sheet_name='Registro')
name_column = promotio_register.iloc[1].tolist()
promotio_register = promotio_register.drop([0,1])
promotio_register.columns = name_column
promotio_register
promotio_register_EC = promotio_register[promotio_register['País'] == 'Ecuador']
promotio_register_EC
# Out:
#      NaN                   Tipo     País                Localidades      Mes  \
# 2    1.0  Aviso de promoción CS  Ecuador                      Quito    Enero
# 3    2.0  Aviso de promoción CS  Ecuador          Cuenca y Riobamba    Enero
# 4    3.0  Aviso de promoción CS  Ecuador                   Riobamba  Febrero
# 25  25.0  Aviso de promoción CS  Ecuador  Quito, Guayaquil y Cuenca    Julio
#
#    Inversión Form Inv Lead Total Inv Alcance Costo por persona Interacciones  \
# 2              20        0        20     578         0.0346021            18
# 3              20        0        20   22163       0.000902405           980
# 4              20        0        20     719         0.0278164            65
# 25              0       30        30   22604         0.0013272           316
#
#    # de días # personas form # personas leads # total personas #Inscritos  \
# 2          5              84                0               84         10
# ...

# %%
# Out:
#      NaN                          Tipo         País  \
# 2    1.0         Aviso de promoción CS      Ecuador
# 3    2.0         Aviso de promoción CS      Ecuador
# 4    3.0         Aviso de promoción CS      Ecuador
# 5    4.0         Aviso de promoción CS      Bolivia
# 6    5.0  Branding video institucional     5 países
# 7    6.0         Aviso de promoción CM      Bolivia
# 8    8.0         Aviso de promoción CS      Bolivia
# 9    9.0            Aviso Promocion CS         Perú
# 10  10.0               Branding página         Perú
# 11  11.0         Aviso de promoción CS      Bolivia
# 12  12.0         Aviso de promoción CS      Bolivia
# 13  13.0         Aviso de promoción CS      Bolivia
# 14  14.0         Aviso de promoción CS      Bolivia
# 15  15.0         Aviso de promoción CS  El Salvador
# 16  16.0   Aviso de promoción CM SAFCI      Bolivia
# 17  17.0         Aviso de promoción CS      Bolivia
# 18  18.0         Aviso de promoción CS         Perú
# ...

# %%
df_register.dropna()
# Out:
#     Unnamed: 0                   Unnamed: 1   Unnamed: 2  \
# 8          8.0        Aviso de promoción CS      Bolivia
# 9          9.0           Aviso Promocion CS         Perú
# 12        12.0        Aviso de promoción CS      Bolivia
# 13        13.0        Aviso de promoción CS      Bolivia
# 14        14.0        Aviso de promoción CS      Bolivia
# 15        15.0        Aviso de promoción CS  El Salvador
# 17        17.0        Aviso de promoción CS      Bolivia
# 18        18.0        Aviso de promoción CS         Perú
# 19        19.0        Aviso de promoción CS     Honduras
# 23        23.0  Aviso de promoción CM SAFCI      Bolivia
# 29        29.0           Aviso Promocion CS      Bolivia
# 31        31.0           Aviso Promocion CS  El Salvador
# 32        32.0           Aviso Promocion CS      Bolivia
#
#                                 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8                               Santa Cruz       Marzo         20          0
# ...
